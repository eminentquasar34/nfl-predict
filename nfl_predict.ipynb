# %% [markdown]
# <a href="https://colab.research.google.com/github/eminentquasar34/nfl-predict/blob/main/nfl_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

s = pd.Series([11, 22, 14, 9])

s

dates = pd.date_range("20130101", periods=6)

dates

df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df

df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo"
    }
)

df2

df2.dtypes

df2.A

df.head()

df.tail(3)

df.index

df.columns

df.to_numpy()

df.describe()

df.T

df.sort_index(axis=1, ascending=False)

df.sort_values(by="B")

df["A"]

df[0:2]

df.loc[dates[0]]

df.loc[:, ["A", "C"]]

df.loc[dates[1], "C"]

df.at[dates[1], "C"]

df.iloc[3]

df.iloc[2:5]

df.iloc[2:5, 0:2]

df[df["A"] > 0]

s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130101", periods=6))

s1

df["E"] = s1
df

df.at[dates[0], "A"] = 0
df

df.iat[0, 1] = 0
df
df.loc[:, "D"] = np.array([5] * len(df))
df

df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D  E
# 2013-01-01  0.000000  0.000000 -0.529073 -5.0 -1
# 2013-01-02 -1.566921 -0.376197 -0.752176 -5.0 -2
# 2013-01-03 -1.499822 -0.106418 -2.120409 -5.0 -3
# 2013-01-04 -1.280776 -1.638203 -0.467469 -5.0 -4
# 2013-01-05 -1.293218 -0.150080 -0.364051 -5.0 -5
# 2013-01-06 -0.731141 -1.516635 -2.002319 -5.0 -6
